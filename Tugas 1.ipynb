# %%
import tweepy
import datetime
from tweepy import OAuthHandler, Stream, StreamListener

# Consumer keys and access tokens, used for OAuth
consumer_key="eNly7n62NgPBr1cwUUsLDXvWN"
consumer_secret="iHPbHMLum74zSFz0NCwERWnnw0ZCfR4bGCMuUIDSE3czlDY9Sq"
access_token="702183804-JvE0qIBEvqfv5Al3KGuEVsbhbyhRVhLn4kqJ5KN9"
access_token_secret="WoXhuxup1EpbFXS8O3McBABteUvcPvyerOyrNNNjGmD3f"

# OAuth process, using the keys and tokens
auth = OAuthHandler(consumer_key, consumer_secret,)
auth.set_access_token(access_token, access_token_secret)

# Creation of the actual interface, using authentication
api = tweepy.API(auth)

# %%
#Mengambil tweet dari username lain (JeromePolin) 
#Print dengan format json
user_tweets = api.user_timeline(screen_name='JeromePolin', count=200, tweet_mode="extended",  )
for tweet in user_tweets:
    print(tweet._json)
# Out:
# {'created_at': 'Sun Oct 27 18:34:20 +0000 2019', 'id': 1188524345984872449, 'id_str': '1188524345984872449', 'full_text': '@leo_edw Kevin ga bucin kaya kamu', 'truncated': False, 'display_text_range': [9, 33], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'leo_edw', 'name': 'Leonardo Edwin', 'id': 537176441, 'id_str': '537176441', 'indices': [0, 8]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1188513585061715968, 'in_reply_to_status_id_str': '1188513585061715968', 'in_reply_to_user_id': 537176441, 'in_reply_to_user_id_str': '537176441', 'in_reply_to_screen_name': 'leo_edw', 'user': {'id': 1043820778519580672, 'id_str': '1043820778519580672', 'name': 'Jerome Polin Sijabat', 'screen_name': 'JeromePolin', 'location': 'Japan', 'description': 'Jurusan Matematika Terapan & Melucu Harus Garing Waseda University 早稲田大学| https://t.co/FOWPRPXjlr | business: promomantappu@g
# ...

# %%
#membuat variable list
the_list = []
tweet_jerome = api.user_timeline(screen_name='JeromePolin', count=200, tweet_mode="extended")
startDate = datetime.datetime(2019, 10, 22, 0, 0, 0)
endDate =   datetime.datetime(2019, 10, 24, 0, 0, 0)

#menambahkan objek tweet._json kedalam variable the_list
for tweet in tweet_jerome:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        the_list.append(tweet._json)

# %%
import pandas
#membaca file the_list dan menjadikan tabel
myData = pandas.DataFrame(the_list)
myData
# Out:
#                         created_at                   id               id_str  \
# 0   Wed Oct 23 16:45:14 +0000 2019  1187047337635434496  1187047337635434496
# 1   Wed Oct 23 15:49:15 +0000 2019  1187033251379990528  1187033251379990528
# 2   Wed Oct 23 15:40:48 +0000 2019  1187031124448399360  1187031124448399360
# 3   Wed Oct 23 15:40:48 +0000 2019  1187031123127201794  1187031123127201794
# 4   Wed Oct 23 15:40:48 +0000 2019  1187031123051700225  1187031123051700225
# 5   Wed Oct 23 15:33:00 +0000 2019  1187029160180379648  1187029160180379648
# 6   Wed Oct 23 15:28:27 +0000 2019  1187028014099357696  1187028014099357696
# 7   Wed Oct 23 15:24:19 +0000 2019  1187026977145810944  1187026977145810944
# 8   Wed Oct 23 15:18:43 +0000 2019  1187025567306022912  1187025567306022912
# 9   Wed Oct 23 14:55:14 +0000 2019  1187019657149997059  1187019657149997059
# 10  Wed Oct 23 14:54:46 +0000 2019  1187019539575263233  1187019539575263233
# ...
